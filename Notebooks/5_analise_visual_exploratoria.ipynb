# %% [markdown]
# # 📈 --- **Análise Visual Exploratória** ---

# %% [markdown]
# ## 1. Preparação do ambiente

# %%
# 📦 Pacotes principais
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# 📥 Carregando os dados
df_analise_ex_incendios = pd.read_pickle('../data/processados/modelos/final_modelo_incendios.pkl')


# ⛲ Visualizando os dados
df_analise_ex_incendios.head()
# Out:
#         data              municipio estacao_ref    lat     lon  risco_fogo  \
# 0 2020-01-16  Alta Floresta D'Oeste      Cacoal -12.38 -62.206   11.886667
# 1 2020-01-16  Alta Floresta D'Oeste      Cacoal -12.38 -62.206   11.960000
# 2 2020-01-16  Alta Floresta D'Oeste      Cacoal -12.38 -62.206   15.953333
# 3 2020-01-16  Alta Floresta D'Oeste      Cacoal -12.38 -62.206   21.373333
# 4 2020-01-16  Alta Floresta D'Oeste      Cacoal -12.38 -62.206   23.433333
#
#    temp_media  umidade_relativa  precipitacao  dias_sem_chuva  \
# 0   21.966667         89.666667           7.6               0
# 1   22.900000         90.666667           0.2               0
# 2   25.133333         81.333333           0.0               1
# 3   27.933333         68.000000           0.0               2
# 4   28.833333         63.333333           0.0               3
#
#   intensidade_chuva  fumaca_media
# 0    Chuva moderada            14
# 1        Chuva leve            14
# 2         Sem chuva            14
# 3         Sem chuva            14
# 4         Sem chuva            14

# %% [markdown]
# ## 2. Dimensão e tipos dos dados

# %%
print(f"🔢 Total de registros: {df_analise_ex_incendios.shape[0]}")
print(f"📏 Total de colunas: {df_analise_ex_incendios.shape[1]}")

# Tipos de dados
df_analise_ex_incendios.info()
# Out:
# 🔢 Total de registros: 150008
# 📏 Total de colunas: 12
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150008 entries, 0 to 150007
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   data               150008 non-null  datetime64[ns]
#  1   municipio          150008 non-null  object
#  2   estacao_ref        150008 non-null  object
#  3   lat                150008 non-null  float64
#  4   lon                150008 non-null  float64
#  5   risco_fogo         150008 non-null  float64
#  6   temp_media         150008 non-null  float64
#  7   umidade_relativa   150008 non-null  float64
#  8   precipitacao       150008 non-null  float64
#  9   dias_sem_chuva     150008 non-null  int64
#  10  intensidade_chuva  150008 non-null  object
#  11  fumaca_media       150008 non-null  int64
# dtypes: datetime64[ns](1), float64(6), int64(2), object(3)
# memory usage: 13.7+ MB

# %% [markdown]
# ### 2.1 Verificando dados ausentes

# %%
df_analise_ex_incendios.isnull().sum()  # Verificando valores nulos
# Out:
# data                 0
# municipio            0
# estacao_ref          0
# lat                  0
# lon                  0
# risco_fogo           0
# temp_media           0
# umidade_relativa     0
# precipitacao         0
# dias_sem_chuva       0
# intensidade_chuva    0
# fumaca_media         0
# dtype: int64

# %% [markdown]
# ## 🔍 3. Estatísticas descritivas básicas

# %%
df_analise_ex_incendios.describe()
# Out:
#                                 data            lat            lon  \
# count                         150008  150008.000000  150008.000000
# mean   2023-10-06 08:14:29.905605120     -10.669221     -62.733772
# min              2020-01-16 00:00:00     -13.693030     -66.779500
# 25%              2023-09-05 00:00:00     -12.273000     -63.674170
# 50%              2024-07-11 00:00:00     -10.690000     -62.703080
# 75%              2024-08-24 00:00:00      -8.882440     -61.728000
# max              2024-12-30 00:00:00      -7.977510     -59.833000
# std                              NaN       1.718168       1.486218
#
#           risco_fogo     temp_media  umidade_relativa   precipitacao  \
# count  150008.000000  150008.000000     150008.000000  150008.000000
# mean      753.395803      30.543776         50.549677       0.090207
# min         8.700000       9.433333         10.666667       0.000000
# 25%        59.845000      27.100000         32.333333       0.000000
# 50%       204.683333      31.433333         46.666667       0.000000
# 75%       883.953333      34.466667         67.333333       0.000000
# max      4922.460000      39.400000         98.666667      88.400000
# std      1149.575650       4.722000         21.667103       1.331867
#
#        dias_sem_chuva   fumaca_media
# count   150008.000000  150008.000000
# mean      2421.143986     323.845008
# min          0.000000       1.000000
# 25%        111.000000      52.000000
# 50%        587.000000     156.000000
# 75%       2850.000000     462.000000
# max      16296.000000    1536.000000
# std       3828.094872     385.269672

# %% [markdown]
# ## 📊 4. Distribuição das variáveis principais

# %% [markdown]
# 🧯 Risco de Fogo

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df_analise_ex_incendios['risco_fogo'], kde=True, bins=30, color='firebrick')
plt.title('Distribuição do Risco de Fogo')
plt.xlabel('Risco de Fogo')
plt.ylabel('Frequência')
plt.grid(True)
plt.show()

# %% [markdown]
# 🌡️ Temperatura Média

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x=df_analise_ex_incendios['temp_media'], color='orange')
plt.title('Boxplot da Temperatura Média')
plt.xlabel('Temperatura (°C)')
plt.grid(True)
plt.show()

# %% [markdown]
# 📈 Distribuição da Umidade Relativa

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
sns.histplot(df_analise_ex_incendios['umidade_relativa'], bins=30, kde=True, color='skyblue')
plt.title('Distribuição da Umidade Relativa (%)')
plt.xlabel('Umidade Relativa (%)')
plt.ylabel('Frequência')
plt.grid(True)
plt.show()

# %% [markdown]
# 🧮 Estatísticas descritivas

# %%
df_analise_ex_incendios['umidade_relativa'].describe()
# Out:
# count    150008.000000
# mean         50.549677
# std          21.667103
# min          10.666667
# 25%          32.333333
# 50%          46.666667
# 75%          67.333333
# max          98.666667
# Name: umidade_relativa, dtype: float64

# %% [markdown]
# 📆 Evolução temporal da Umidade Relativa

# %%
df_analise_ex_incendios['data'] = pd.to_datetime(df_analise_ex_incendios['data'])

df_analise_ex_incendios.groupby('data')['umidade_relativa'].mean().plot(figsize=(12,6), color='green')
plt.title('Média diária da Umidade Relativa ao longo do tempo')
plt.xlabel('Data')
plt.ylabel('Umidade Relativa (%)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🌧️ 1. Umidade Relativa
# 📈 Distribuição

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df_analise_ex_incendios['umidade_relativa'], bins=30, kde=True, color='skyblue')
plt.title('Distribuição da Umidade Relativa (%)')
plt.xlabel('Umidade Relativa (%)')
plt.ylabel('Frequência')
plt.grid(True)
plt.show()

# %% [markdown]
# 📆 Evolução Temporal

# %%
df_analise_ex_incendios.groupby('data')['precipitacao'].mean().plot(figsize=(12,6), color='darkblue')
plt.title('Média Diária da Precipitação')
plt.xlabel('Data')
plt.ylabel('Precipitação (mm)')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 🌵 3. Dias sem Chuva

# %% [markdown]
# 📈 Distribuição

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df_analise_ex_incendios['dias_sem_chuva'], bins=20, kde=False, color='orange')
plt.title('Distribuição de Dias Sem Chuva')
plt.xlabel('Dias Sem Chuva')
plt.ylabel('Frequência')
plt.grid(True)
plt.show()

# %% [markdown]
# 📊 Estatísticas

# %%
df_analise_ex_incendios['dias_sem_chuva'].describe()
# Out:
# count    150008.000000
# mean       2421.143986
# std        3828.094872
# min           0.000000
# 25%         111.000000
# 50%         587.000000
# 75%        2850.000000
# max       16296.000000
# Name: dias_sem_chuva, dtype: float64

# %%
df_analise_ex_incendios[df_analise_ex_incendios['dias_sem_chuva'] > 1000]  # ou > 365, que já seria um ano sem chuva
# Out:
#              data              municipio estacao_ref       lat      lon  \
# 1100   2020-09-10  Alta Floresta D'Oeste      Cacoal -12.74000 -62.0690
# 1101   2020-09-10  Alta Floresta D'Oeste      Cacoal -12.74000 -62.0690
# 1102   2020-09-10  Alta Floresta D'Oeste      Cacoal -12.74000 -62.0690
# 1103   2020-09-10  Alta Floresta D'Oeste      Cacoal -12.74000 -62.0690
# 1104   2020-09-10  Alta Floresta D'Oeste      Cacoal -12.74000 -62.0690
# ...           ...                    ...         ...       ...      ...
# 149350 2024-09-18                Vilhena     Vilhena -11.59378 -60.3246
# 149351 2024-09-18                Vilhena     Vilhena -11.59378 -60.3246
# 149352 2024-09-18                Vilhena     Vilhena -11.59378 -60.3246
# 149353 2024-09-18                Vilhena     Vilhena -11.59378 -60.3246
# 149354 2024-09-18                Vilhena     Vilhena -11.59378 -60.3246
#
#          risco_fogo  temp_media  umidade_relativa  precipitacao  \
# 1100     340.146667   38.866667         19.000000           0.0
# 1101     338.813333   37.533333         22.666667           0.0
# 1102     337.653333   36.133333         25.666667           0.0
# 1103     335.986667   34.466667         30.000000           0.0
# 1104     334.120000   32.800000         35.000000           0.0
# ...             ...         ...               ...           ...
# 149350  1784.733333   30.333333         45.333333           0.0
# 149351  1787.133333   31.833333         40.333333           0.0
# 149352  1789.526667   33.566667         35.666667           0.0
# 149353  1790.000000   33.500000         35.000000           0.0
# 149354  1790.920000   33.800000         33.333333           0.0
#
#         dias_sem_chuva intensidade_chuva  fumaca_media
# 1100              1001         Sem chuva           221
# 1101              1002         Sem chuva           221
# 1102              1003         Sem chuva           221
# 1103              1004         Sem chuva           221
# 1104              1005         Sem chuva           221
# ...                ...               ...           ...
# 149350            5854         Sem chuva            26
# 149351            5855         Sem chuva            26
# 149352            5856         Sem chuva            26
# 149353            5857         Sem chuva            26
# 149354            5858         Sem chuva            26
#
# [61189 rows x 12 columns]

# %%
df_analise_ex_incendios['dias_sem_chuva'].sort_values(ascending=False).head(20)
# Out:
# 110795    16296
# 110794    16295
# 110793    16294
# 110792    16293
# 110791    16292
# 110790    16291
# 110789    16290
# 110788    16289
# 110787    16288
# 110786    16287
# 110785    16286
# 110784    16285
# 110783    16284
# 110782    16283
# 110781    16282
# 110780    16281
# 110779    16280
# 110778    16279
# 110777    16278
# 110776    16277
# Name: dias_sem_chuva, dtype: int64

# %% [markdown]
# ## Corrigir a numeração de dias sem chuva com uma média ponderada para reduzir a quantidade de casas decimais desnecessárias

# %%
import numpy as np

# Define o limite razoável de 365 dias
limite_dias_sem_chuva = 90

# Transforma valores acima disso (ou negativos, se houver) em NaN
df_analise_ex_incendios['dias_sem_chuva'] = df_analise_ex_incendios['dias_sem_chuva'].apply(lambda x: x if 0 <= x <= limite_dias_sem_chuva else np.nan)

# %%
print(df_analise_ex_incendios['dias_sem_chuva'].describe())
print(df_analise_ex_incendios['dias_sem_chuva'].isna().sum())
# Out:
# count    34101.000000
# mean        27.229553
# std         27.037940
# min          0.000000
# 25%          5.000000
# 50%         15.000000
# 75%         48.000000
# max         90.000000
# Name: dias_sem_chuva, dtype: float64
# 115907

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,5))
sns.histplot(df_analise_ex_incendios['dias_sem_chuva'], kde=True, bins=30, color='orange')
plt.title('Distribuição Corrigida de Dias Sem Chuva')
plt.xlabel('Dias Sem Chuva')
plt.ylabel('Frequência')
plt.grid(True)
plt.show()

# %% [markdown]
# 📆 Evolução Temporal

# %%
df_analise_ex_incendios.groupby('data')['dias_sem_chuva'].mean().plot(figsize=(12,6), color='darkorange')
plt.title('Média de Dias Sem Chuva ao Longo do Tempo')
plt.xlabel('Data')
plt.ylabel('Dias Sem Chuva')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 🌫️ 4. Fumaça Média
# 📈 Distribuição

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df_analise_ex_incendios['fumaca_media'], bins=30, kde=True, color='gray')
plt.title('Distribuição da Fumaça Média Diária')
plt.xlabel('Fumaça Média')
plt.ylabel('Frequência')
plt.grid(True)
plt.show()

# %% [markdown]
# 📊 Estatísticas

# %%
df_analise_ex_incendios['fumaca_media'].describe()
# Out:
# count    150008.000000
# mean        323.845008
# std         385.269672
# min           1.000000
# 25%          52.000000
# 50%         156.000000
# 75%         462.000000
# max        1536.000000
# Name: fumaca_media, dtype: float64

# %% [markdown]
# ## 5. Análise de Outliers Extremos (Top 1%)
# 👉 Objetivo:
# Identificar os dias sem chuva fora da curva, que podem ser decisivos no risco de queimadas.

# %%
# Limite superior do top 1%
limite_1pct = df_analise_ex_incendios['dias_sem_chuva'].quantile(0.99)


plt.figure(figsize=(10, 4))
sns.boxplot(x=df_analise_ex_incendios['dias_sem_chuva'])
plt.title('Boxplot de Dias Sem Chuva (Top 1% como Outliers)')
plt.axvline(limite_1pct, color='red', linestyle='--', label=f'99º percentil: {limite_1pct:.1f}')
plt.legend()
plt.grid(True)
plt.show()

# %%
outliers_extremos = df_analise_ex_incendios[df_analise_ex_incendios['dias_sem_chuva'] > limite_1pct]
# Exibir

# %% [markdown]
# ## 6. Agrupamento em Faixas de Risco 🌡️

# %% [markdown]
# Transformar dias_sem_chuva em faixas de risco, o que facilita análises comparativas e modelagens futuras.
# **PS:** Adicionei mais uma coluna ao dataset aqui

# %%
def classificar_risco_chuva(dias):
    if dias <= 5:
        return 'Baixo'
    elif dias <= 15:
        return 'Moderado'
    else:
        return 'Alto'

df_analise_ex_incendios['risco_dias_sem_chuva'] = df_analise_ex_incendios['dias_sem_chuva'].apply(classificar_risco_chuva)

# %%
df_analise_ex_incendios['risco_dias_sem_chuva'].value_counts().plot(kind='bar', color='orange')
plt.title('Distribuição das Faixas de Risco (Dias Sem Chuva)')
plt.xlabel('Nível de Risco')
plt.ylabel('Frequência')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 7. Correlação com Fumaça Média ou Risco de Fogo 🔥
# 🧪 Hipótese: Mais dias sem chuva = mais fumaça (ou mais focos).

# %%
# Correlação direta
correlacao = df_analise_ex_incendios[['dias_sem_chuva', 'fumaca_media']].corr().iloc[0, 1]
print(f"Correlação entre Dias Sem Chuva e Fumaça Média: {correlacao:.2f}")
# Out:
# Correlação entre Dias Sem Chuva e Fumaça Média: -0.14

# %%
sns.scatterplot(data=df_analise_ex_incendios, x='dias_sem_chuva', y='fumaca_media', alpha=0.3)
plt.title('Dispersão: Dias Sem Chuva vs Fumaça Média')
plt.xlabel('Dias Sem Chuva')
plt.ylabel('Fumaça Média')
plt.grid(True)
plt.show()

# %% [markdown]
# 🛠️ Soluções para Melhorar o Gráfico de Dispersão
# Jitter (adicionar ruído visual leve)
# Serve pra espalhar visualmente pontos com mesmo valor. Não altera os dados, só ajuda a ver os empilhamentos.

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(
    x=df_analise_ex_incendios['dias_sem_chuva'] + np.random.normal(0, 0.3, size=len(df_analise_ex_incendios)),
    y=df_analise_ex_incendios['fumaca_media'] + np.random.normal(0, 1.5, size=len(df_analise_ex_incendios)),
    alpha=0.3
)
plt.title('Dispersão com Jitter: Dias Sem Chuva vs Fumaça Média')
plt.xlabel('Dias Sem Chuva (com jitter)')
plt.ylabel('Fumaça Média (com jitter)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hexbin(df_analise_ex_incendios['dias_sem_chuva'], df_analise_ex_incendios['fumaca_media'], gridsize=40, cmap='viridis', mincnt=1)
plt.colorbar(label='Contagem')
plt.title('Densidade: Dias Sem Chuva vs Fumaça Média')
plt.xlabel('Dias Sem Chuva')
plt.ylabel('Fumaça Média')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(
    x=df_analise_ex_incendios['dias_sem_chuva'], 
    y=df_analise_ex_incendios['fumaca_media'], 
    fill=True, 
    cmap="YlOrBr", 
    thresh=0.05
)
plt.title('Densidade KDE: Dias Sem Chuva vs Fumaça Média')
plt.xlabel('Dias Sem Chuva')
plt.ylabel('Fumaça Média')
plt.grid(True)
plt.show()

# %% [markdown]
# # **Análise Exploratória Geográfica 🗺🌏**

# %% [markdown]
# 📚 Seção: Visualização Geográfica com Folium
# ⚙️ Lembrar aqui que preciso instalar o Geopandas 🗺
# pip install folium geopandas

# %% [markdown]
# # 🔽⬇ --- Importações Necessárias ---

# %%
import folium
from folium.plugins import MarkerCluster
import geopandas as gpd

# %% [markdown]
# # 🌍 1. Dados Base - Coordenadas e Municipios

# %% [markdown]
# ### Importante: Cria um novo dataframe para tratar especifiamente os dados geográficos e sua relação com fumaca_media e dias sem chuva

# %%
df_geo = df_analise_ex_incendios[["municipio", "dias_sem_chuva", "fumaca_media", "lat", "lon"]].dropna()

# %%
df_geo.head()
# Out:
#                municipio  dias_sem_chuva  fumaca_media    lat     lon
# 0  Alta Floresta D'Oeste             0.0            14 -12.38 -62.206
# 1  Alta Floresta D'Oeste             0.0            14 -12.38 -62.206
# 2  Alta Floresta D'Oeste             1.0            14 -12.38 -62.206
# 3  Alta Floresta D'Oeste             2.0            14 -12.38 -62.206
# 4  Alta Floresta D'Oeste             3.0            14 -12.38 -62.206

# %% [markdown]
# # 🗺️ 2. Mapa Interativo Básico com Fumaça Média

# %% [markdown]
# # Centro do estado de Rondônia
# mapa_ro = folium.Map(location=[-10.9, -62.8], zoom_start=6, tiles='CartoDB positron')
#
# # Marcadores agrupados
# cluster = MarkerCluster().add_to(mapa_ro)
#
# for _, row in df_geo.iterrows():
#     popup_text = f"""
#     <strong>Município:</strong> {row['municipio']}<br>
#     <strong>Dias sem chuva:</strong> {row['dias_sem_chuva']}<br>
#     <strong>Fumaça média:</strong> {row['fumaca_media']}
#     """
#     cor = 'green'
#     if row['dias_sem_chuva'] > 15:
#         cor = 'red'
#     elif row['dias_sem_chuva'] > 5:
#         cor = 'orange'
#
#     folium.CircleMarker(
#         location=[row['lat'], row['lon']],
#         radius=5,
#         popup=folium.Popup(popup_text, max_width=300),
#         color=cor,
#         fill=True,
#         fill_color=cor,
#         fill_opacity=0.7
#     ).add_to(cluster)
#
# mapa_ro

# %%
#mapa_ro.save("../assets/mapas/mapa_marcadores.html")
#print("🗺️ Mapa salvo em ../assets/mapas/mapa_marcadores.html")

# %% [markdown]
# ## O número mostrado no centro da bola NÃO é o valor da fumaça, nem dias sem chuva — é a quantidade de marcadores naquela área. Podendo ser, ou seja, se um grupo tiver 10 marcadores próximos, ele mostra “10”.

# %% [markdown]
# for _, row in df_geo.iterrows():
#     popup_text = f"""
#     <strong>Município:</strong> {row['municipio']}<br>
#     <strong>Dias sem chuva:</strong> {row['dias_sem_chuva']}<br>
#     <strong>Fumaça média:</strong> {row['fumaca_media']}
#     """
#     folium.CircleMarker(
#         location=[row['lat'], row['lon']],
#         radius=6,
#         popup=folium.Popup(popup_text, max_width=300),
#         color='blue',
#         fill=True,
#         fill_color='blue',
#         fill_opacity=0.6
#     ).add_to(mapa_ro)

# %% [markdown]
# ## Carregar o perímetro dos municípios no Mapa de Rondônia 🗺

# %%
import geopandas as gpd

# Carregar o GeoJSON dos municípios de Rondônia
gdf_municipios = gpd.read_file('../assets/jsons/municipios_ro.geojson.json')

# Verificar as primeiras linhas 
gdf_municipios.head()
# Out:
#         id                   name            description  \
# 0  1100015  Alta Floresta D'Oeste  Alta Floresta D'Oeste
# 1  1100023              Ariquemes              Ariquemes
# 2  1100031                 Cabixi                 Cabixi
# 3  1100049                 Cacoal                 Cacoal
# 4  1100056             Cerejeiras             Cerejeiras
#
#                                             geometry
# 0  POLYGON ((-62.18209 -11.86686, -62.1623 -11.87...
# 1  POLYGON ((-62.53595 -9.73182, -62.50782 -9.754...
# 2  POLYGON ((-60.3994 -13.45584, -60.40195 -13.46...
# 3  POLYGON ((-61.00051 -11.39796, -61.01794 -11.4...
# 4  POLYGON ((-61.50047 -13.00392, -61.47901 -13.0...

# %%
df_analise_ex_incendios.groupby('municipio')['data'].nunique().sort_values(ascending=False)
# Out:
# municipio
# Porto Velho                  241
# Vilhena                      180
# Pimenteiras Do Oeste         173
# Pimenta Bueno                165
# Candeias Do Jamari           158
# Alta Floresta D'Oeste        139
# Guajara-Mirim                135
# Sao Francisco Do Guapore     126
# Sao Miguel Do Guapore         94
# Costa Marques                 88
# Espigao D'Oeste               88
# Chupinguaia                   83
# Itapua Do Oeste               79
# Ji-Parana                     66
# Cerejeiras                    53
# Corumbiara                    49
# Mirante Da Serra              48
# Alto Alegre Dos Parecis       45
# Alvorada D'Oeste              39
# Cabixi                        38
# Seringueiras                  38
# Ouro Preto Do Oeste           38
# Cujubim                       34
# Machadinho D'Oeste            33
# Alto Paraiso                  32
# Parecis                       31
# Ariquemes                     28
# Nova Brasilandia D'Oeste      27
# Rolim De Moura                17
# Buritis                       16
# Ministro Andreazza            15
# Presidente Medici             13
# Urupa                         13
# Castanheiras                  11
# Vale Do Anari                 11
# Monte Negro                   10
# Rio Crespo                    10
# Cacaulandia                    9
# Novo Horizonte Do Oeste        8
# Governador Jorge Teixeira      7
# Campo Novo De Rondonia         5
# Sao Felipe D'Oeste             5
# Santa Luzia D'Oeste            5
# Primavera De Rondonia          4
# Nova Uniao                     4
# Jaru                           3
# Colorado Do Oeste              3
# Theobroma                      2
# Vale Do Paraiso                2
# Name: data, dtype: int64

# %% [markdown]
# # camada temática

# %% [markdown]
# import folium
#
# # Criação do mapa base centralizado em Rondônia
# mapa_ro = folium.Map(location=[-10.9, -62.8], zoom_start=6)
#
# # Adicionando o choropleth
# folium.Choropleth(
#     geo_data="../assets/jsons/municipios_ro.geojson.json",  # Caminho para o arquivo GeoJSON
#     name="Risco de Fogo",
#     data=df_agg,  # DataFrame com dados agregados
#     columns=["municipio", "risco_fogo"],
#     key_on="feature.properties.nome",  # A propriedade no GeoJSON que corresponde ao nome do município
#     fill_color="YlOrRd",
#     fill_opacity=0.7,
#     line_opacity=0.2,
#     legend_name="Risco de Fogo em Rondônia"
# ).add_to(mapa_ro)
#
# # Adicionar controle de camadas
# folium.LayerControl().add_to(mapa_ro)
#
# # Exibir
# mapa_ro

# %%
df_analise_ex_incendios.columns
# Out:
# Index(['data', 'municipio', 'estacao_ref', 'lat', 'lon', 'risco_fogo',
#        'temp_media', 'umidade_relativa', 'precipitacao', 'dias_sem_chuva',
#        'intensidade_chuva', 'fumaca_media'],
#       dtype='object')

# %%
df_analise_ex_incendios.head()
# Out:
#         data              municipio estacao_ref    lat     lon  risco_fogo  \
# 0 2020-01-16  Alta Floresta D'Oeste      Cacoal -12.38 -62.206   11.886667
# 1 2020-01-16  Alta Floresta D'Oeste      Cacoal -12.38 -62.206   11.960000
# 2 2020-01-16  Alta Floresta D'Oeste      Cacoal -12.38 -62.206   15.953333
# 3 2020-01-16  Alta Floresta D'Oeste      Cacoal -12.38 -62.206   21.373333
# 4 2020-01-16  Alta Floresta D'Oeste      Cacoal -12.38 -62.206   23.433333
#
#    temp_media  umidade_relativa  precipitacao  dias_sem_chuva  \
# 0   21.966667         89.666667           7.6               0
# 1   22.900000         90.666667           0.2               0
# 2   25.133333         81.333333           0.0               1
# 3   27.933333         68.000000           0.0               2
# 4   28.833333         63.333333           0.0               3
#
#   intensidade_chuva  fumaca_media
# 0    Chuva moderada            14
# 1        Chuva leve            14
# 2         Sem chuva            14
# 3         Sem chuva            14
# 4         Sem chuva            14

# %% [markdown]
# ## Agregando os dados por município

# %%
# Agrupar e calcular as médias por município
df_agg_municipios = df_analise_ex_incendios.groupby('municipio', as_index=False).agg({
    'lat': 'mean',
    'lon': 'mean',
    'risco_fogo': 'mean',
    'temp_media': 'mean',
    'umidade_relativa': 'mean',
    'precipitacao': 'mean',
    'dias_sem_chuva': 'mean',
    'fumaca_media': 'mean',
    'dias_sem_chuva': 'mean'
})

# %% [markdown]
# ## Arredondar valores para não ficar com casas decimais

# %%
df_agg_municipios = df_agg_municipios.round(2)

# %%
df_agg_municipios.head()
# Out:
#                  municipio    lat    lon  risco_fogo  temp_media  \
# 0    Alta Floresta D'Oeste -12.66 -62.33      129.04       31.89
# 1  Alto Alegre Dos Parecis -12.77 -61.97      126.86       30.21
# 2             Alto Paraiso  -9.69 -63.38       78.45       30.55
# 3         Alvorada D'Oeste -11.33 -62.69      149.36       31.23
# 4                Ariquemes  -9.93 -62.90       60.22       30.70
#
#    umidade_relativa  precipitacao  dias_sem_chuva  fumaca_media
# 0             48.88          0.16          336.47        119.13
# 1             47.91          0.02          330.52        104.75
# 2             61.65          0.01          182.42         35.59
# 3             47.46          0.03          403.70         96.15
# 4             56.66          0.01          116.44         31.98

# %% [markdown]
# # Juntar dados tabulares com geodados

# %% [markdown]
# ### Geodataframe final

# %%
import geopandas as gpd
import pandas as pd

# 1. Carregar o GeoJSON dos municípios de RO
gdf_municipios = gpd.read_file('../assets/jsons/municipios_ro.geojson.json')

# 2. Verificar e normalizar os nomes dos municípios (isso é MUITO importante)
gdf_municipios["municipio"] = gdf_municipios["name"].str.strip().str.upper()
df_agg_municipios["municipio"] = df_agg_municipios["municipio"].str.strip().str.upper()

# 3. Fazer o merge (junção) pelo nome do município
gdf_merged = gdf_municipios.merge(df_agg_municipios, on="municipio", how="left")

# 4. Verificar se a junção deu certo
print(gdf_merged.head())
print("Total de municípios com dados:", gdf_merged['risco_fogo'].notna().sum())
# Out:
#         id                   name            description  \
# 0  1100015  Alta Floresta D'Oeste  Alta Floresta D'Oeste
# 1  1100023              Ariquemes              Ariquemes
# 2  1100031                 Cabixi                 Cabixi
# 3  1100049                 Cacoal                 Cacoal
# 4  1100056             Cerejeiras             Cerejeiras
#
#                                             geometry              municipio  \
# 0  POLYGON ((-62.18209 -11.86686, -62.1623 -11.87...  ALTA FLORESTA D'OESTE
# 1  POLYGON ((-62.53595 -9.73182, -62.50782 -9.754...              ARIQUEMES
# 2  POLYGON ((-60.3994 -13.45584, -60.40195 -13.46...                 CABIXI
# 3  POLYGON ((-61.00051 -11.39796, -61.01794 -11.4...                 CACOAL
# 4  POLYGON ((-61.50047 -13.00392, -61.47901 -13.0...             CEREJEIRAS
#
#      lat    lon  risco_fogo  temp_media  umidade_relativa  precipitacao  \
# 0 -12.66 -62.33      129.04       31.89             48.88          0.16
# 1  -9.93 -62.90       60.22       30.70             56.66          0.01
# 2 -13.51 -60.69       53.67       28.11             58.35          0.15
# 3    NaN    NaN         NaN         NaN               NaN           NaN
# 4 -13.21 -61.55      120.36       29.36             52.57          0.22
#
#    dias_sem_chuva  fumaca_media
# 0          336.47        119.13
# 1          116.44         31.98
# 2           99.79         18.37
# 3             NaN           NaN
# 4          314.61        147.71
# Total de municípios com dados: 33

# %%
gdf_merged.head()
# Out:
#         id                   name            description  \
# 0  1100015  Alta Floresta D'Oeste  Alta Floresta D'Oeste
# 1  1100023              Ariquemes              Ariquemes
# 2  1100031                 Cabixi                 Cabixi
# 3  1100049                 Cacoal                 Cacoal
# 4  1100056             Cerejeiras             Cerejeiras
#
#                                             geometry              municipio  \
# 0  POLYGON ((-62.18209 -11.86686, -62.1623 -11.87...  ALTA FLORESTA D'OESTE
# 1  POLYGON ((-62.53595 -9.73182, -62.50782 -9.754...              ARIQUEMES
# 2  POLYGON ((-60.3994 -13.45584, -60.40195 -13.46...                 CABIXI
# 3  POLYGON ((-61.00051 -11.39796, -61.01794 -11.4...                 CACOAL
# 4  POLYGON ((-61.50047 -13.00392, -61.47901 -13.0...             CEREJEIRAS
#
#      lat    lon  risco_fogo  temp_media  umidade_relativa  precipitacao  \
# 0 -12.66 -62.33      129.04       31.89             48.88          0.16
# 1  -9.93 -62.90       60.22       30.70             56.66          0.01
# 2 -13.51 -60.69       53.67       28.11             58.35          0.15
# 3    NaN    NaN         NaN         NaN               NaN           NaN
# 4 -13.21 -61.55      120.36       29.36             52.57          0.22
#
#    dias_sem_chuva  fumaca_media
# 0          336.47        119.13
# 1          116.44         31.98
# 2           99.79         18.37
# 3             NaN           NaN
# 4          314.61        147.71
